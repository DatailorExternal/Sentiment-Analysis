# %%
import pandas as pd
import numpy as np
import re
import string
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Embedding, SpatialDropout1D, GRU
from tensorflow.keras.optimizers import SGD

df = pd.read_csv('turkish_movie_sentiment_dataset.csv', sep=',')
df.head()
# Out:
#                                              comment      film_name point
# 0  \n                      Jean Reno denince zate...  Sevginin Gücü   5,0
# 1  \n                      Ekşın falan izlemek is...  Sevginin Gücü   5,0
# 2  \n                      Bu yapım hakkında öyle...  Sevginin Gücü   5,0
# 3  \n                      finali yeter... (sting...  Sevginin Gücü   5,0
# 4  \n                      Jean Reno..\r\nbu adam...  Sevginin Gücü   5,0

# %%
#yorumların sağındaki ve solundaki boşlukların silinmesi
comment = lambda x : x[23:-24]

df["comment"] = df["comment"].apply(comment)
df["comment"].head()
# Out:
# 0    Jean Reno denince zaten leon filmi gelir akla ...
# 1    Ekşın falan izlemek istiyorsanız eğer bunu izl...
# 2    Bu yapım hakkında öyle çok şey yazabilirim ki ...
# 3    finali yeter... (sting - shape of my heart)\r\...
# 4    Jean Reno..\r\nbu adam kusursuz biri..\r\nve o...
# Name: comment, dtype: object

# %%
df["point"].value_counts()
# Out:
# 4,0    19958
# 5,0    15873
# 2,5    11433
# 3,5     8565
# 4,5     6983
# 3,0     5499
# 0,5     5150
# 1,0     4917
# 2,0     2433
# 1,5     1464
# 4,6      522
# 3,9      211
# 3,8      100
# 3,7       55
# 3,2       38
# 3,1       26
# Name: point, dtype: int64

# %%
#verilen puanların ilk basamağa yuvarlanması
floatize = lambda x : float(x[0:-2])
df["point"] = df["point"].apply(floatize)
df["point"].value_counts()
# Out:
# 4.0    27463
# 5.0    15873
# 3.0    14494
# 2.0    13866
# 1.0     6381
# 0.0     5150
# Name: point, dtype: int64

# %%
#3 puanın nötr olduğu için kaldırılması, 1 ve 2 puan için 0, 4 ve 5 puan için 1 atanması
df.drop(df[df["point"] == 3].index, inplace = True)
df["point"] = df["point"].replace(1, 0)
df["point"] = df["point"].replace(2, 0)
df["point"] = df["point"].replace(4, 1)
df["point"] = df["point"].replace(5, 1)
df["point"].value_counts()
# Out:
# 1.0    43336
# 0.0    25397
# Name: point, dtype: int64

# %%
df.head()
# Out:
#                                              comment      film_name  point
# 0  Jean Reno denince zaten leon filmi gelir akla ...  Sevginin Gücü    1.0
# 1  Ekşın falan izlemek istiyorsanız eğer bunu izl...  Sevginin Gücü    1.0
# 2  Bu yapım hakkında öyle çok şey yazabilirim ki ...  Sevginin Gücü    1.0
# 3  finali yeter... (sting - shape of my heart)\r\...  Sevginin Gücü    1.0
# 4  Jean Reno..\r\nbu adam kusursuz biri..\r\nve o...  Sevginin Gücü    1.0

# %%
df.reset_index(inplace = True)
df.drop("index", axis = 1, inplace = True)
df.head()
# Out:
#                                              comment      film_name  point
# 0  Jean Reno denince zaten leon filmi gelir akla ...  Sevginin Gücü    1.0
# 1  Ekşın falan izlemek istiyorsanız eğer bunu izl...  Sevginin Gücü    1.0
# 2  Bu yapım hakkında öyle çok şey yazabilirim ki ...  Sevginin Gücü    1.0
# 3  finali yeter... (sting - shape of my heart)\r\...  Sevginin Gücü    1.0
# 4  Jean Reno..\r\nbu adam kusursuz biri..\r\nve o...  Sevginin Gücü    1.0

# %%
#tüm harflerin küçük harfe çevrilmesi
df["comment"] = df["comment"].str.lower()
df.head()
# Out:
#                                              comment      film_name  point
# 0  jean reno denince zaten leon filmi gelir akla ...  Sevginin Gücü    1.0
# 1  ekşın falan izlemek istiyorsanız eğer bunu izl...  Sevginin Gücü    1.0
# 2  bu yapım hakkında öyle çok şey yazabilirim ki ...  Sevginin Gücü    1.0
# 3  finali yeter... (sting - shape of my heart)\r\...  Sevginin Gücü    1.0
# 4  jean reno..\r\nbu adam kusursuz biri..\r\nve o...  Sevginin Gücü    1.0

# %%
#noktalama işaretlerinin kaldırılması
def remove_punctuations(text):
    for punctuation in string.punctuation:
        text = text.replace(punctuation, '')
    return text

df["comment"] = df['comment'].apply(remove_punctuations)
df["comment"] = df["comment"].apply(lambda x: x.replace("\r", " "))
df["comment"] = df["comment"].apply(lambda x: x.replace("\n", " "))
df.head()
# Out:
#                                              comment      film_name  point
# 0  jean reno denince zaten leon filmi gelir akla ...  Sevginin Gücü    1.0
# 1  ekşın falan izlemek istiyorsanız eğer bunu izl...  Sevginin Gücü    1.0
# 2  bu yapım hakkında öyle çok şey yazabilirim ki ...  Sevginin Gücü    1.0
# 3  finali yeter sting  shape of my heart    bazıl...  Sevginin Gücü    1.0
# 4  jean reno  bu adam kusursuz biri  ve oyunculug...  Sevginin Gücü    1.0

# %%
#yorumlardan sayıların kaldırılması
print(df.at[4,'comment'])
df['comment'] = df['comment'].str.replace('\d+', '')
print(df.at[4,'comment'])
df.head()
# Out:
# jean reno  bu adam kusursuz biri  ve oyunculugu müthiş  film ise başyapıt  10
# <ipython-input-11-e0eb961d9e5c>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['comment'] = df['comment'].str.replace('\d+', '')
# jean reno  bu adam kusursuz biri  ve oyunculugu müthiş  film ise başyapıt
#                                              comment      film_name  point
# 0  jean reno denince zaten leon filmi gelir akla ...  Sevginin Gücü    1.0
# 1  ekşın falan izlemek istiyorsanız eğer bunu izl...  Sevginin Gücü    1.0
# 2  bu yapım hakkında öyle çok şey yazabilirim ki ...  Sevginin Gücü    1.0
# 3  finali yeter sting  shape of my heart    bazıl...  Sevginin Gücü    1.0
# 4  jean reno  bu adam kusursuz biri  ve oyunculug...  Sevginin Gücü    1.0

# %%
#etkisiz kelimelerin kaldırılması
stopwords = open('turkce-stop-words.txt','r').read().split()
df['comment_without_stopwords'] = df['comment'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stopwords)]))
df.head()
# Out:
#                                              comment      film_name  point  \
# 0  jean reno denince zaten leon filmi gelir akla ...  Sevginin Gücü    1.0
# 1  ekşın falan izlemek istiyorsanız eğer bunu izl...  Sevginin Gücü    1.0
# 2  bu yapım hakkında öyle çok şey yazabilirim ki ...  Sevginin Gücü    1.0
# 3  finali yeter sting  shape of my heart    bazıl...  Sevginin Gücü    1.0
# 4  jean reno  bu adam kusursuz biri  ve oyunculug...  Sevginin Gücü    1.0
#
#                            comment_without_stopwords
# 0  jean reno denince leon filmi gelir akla izleme...
# 1  ekşın izlemek istiyorsanız eğer izlemeyiin dos...
# 2  yapım hakkında öyle çok şey yazabilirim kitap ...
# 3  finali yeter sting shape of my heart bazıları ...
# 4  jean reno adam kusursuz oyunculugu müthiş film...

# %%
#train ve test verilerinin oluşturulması (%80 train, %20 test)
data = df["comment_without_stopwords"].values.tolist()
target = df["point"].values.tolist()

X_train, X_test, y_train, y_test = train_test_split(data,target,test_size=0.2, random_state = 42)

# %%
#tokenleştirme işlemi
num_words = 10000
tokenizer = Tokenizer(num_words = num_words)
tokenizer.fit_on_texts(data)
tokenizer.word_index
# Out:
# {'film': 1,
#  'çok': 2,
#  'filmi': 3,
#  'iyi': 4,
#  'filmin': 5,
#  'için': 6,
#  'güzel': 7,
#  'bi': 8,
#  'filmde': 9,
#  'bence': 10,
#  'kötü': 11,
#  'değil': 12,
#  'hiç': 13,
#  'gerçekten': 14,
#  'filme': 15,
#  'ilk': 16,
#  'son': 17,
#  'yok': 18,
#  'zaman': 19,
#  'kesinlikle': 20,
#  'başarılı': 21,
#  'şey': 22,
#  'tek': 23,
#  'tavsiye': 24,
#  'sadece': 25,
#  'büyük': 26,
#  'olmuş': 27,
#  'harika': 28,
#  'böyle': 29,
#  'fazla': 30,
#  'olduğunu': 31,
#  'cok': 32,
#  'olduğu': 33,
#  'nasıl': 34,
#  'izledim': 35,
#  'senaryo': 36,
#  'konu': 37,
#  'aynı': 38,
#  'sinema': 39,
#  'farklı': 40,
#  'özellikle': 41,
#  'şekilde': 42,
#  'önce': 43,
#  'komedi': 44,
#  'izlediğim': 45,
#  'mükemmel': 46,
#  'filmleri': 47,
#  'gereken': 48,
#  'yer': 49,
#  'aksiyon': 50,
#  'göre': 51,
#  'korku': 52,
#  'türk': 53,
#  'oyuncu': 54,
#  'oldukça': 55,
#  'filmden': 56,
#  'yönetmen': 57,
#  'rağmen': 58,
#  'filmlerden': 59,
#  'bazı': 60,
#  'izleyin': 61,
#  'uzun': 62,
#  'tüm': 63,
#  'olması': 64,
#  'başka': 65,
#  'konusu': 66,
#  'filmler': 67,
#  'içinde': 68,
#  'çünkü': 69,
#  'filmdi': 70,
#  'gayet': 71,
#  'diğer': 72,
#  'aslında': 73,
#  'oyunculuk': 74,
#  'süper': 75,
#  'gerçek': 76,
#  'the': 77,
#  'mutlaka': 78,
#  'izlerken': 79,
#  'muhteşem': 80,
#  'adam': 81,
#  'öyle': 82,
#  'eğlenceli': 83,
#  'komik': 84,
#  'yeni': 85,
#  'insan': 86,
#  'ayrıca': 87,
#  'artık': 88,
#  'ortaya': 89,
#  'saçma': 90,
#  'filmlerinden': 91,
#  'sahneleri': 92,
#  'sıkıcı': 93,
#  'fil': 94,
#  'devam': 95,
#  'ederim': 96,
#  'etkileyici': 97,
#  'hayal': 98,
#  'yapım': 99,
#  'gerilim': 100,
#  'izlemek': 101,
#  'puan': 102,
#  'sonunda': 103,
#  'sahneler': 104,
#  'hiçbir': 105,
#  'sahne': 106,
#  'berbat': 107,
#  'bütün': 108,
#  'önemli': 109,
#  'dışında': 110,
#  'tekrar': 111,
#  'şu': 112,
#  'sahnesi': 113,
#  'oyuncular': 114,
#  'sonu': 115,
#  'doğru': 116,
#  'basit': 117,
#  'filmdeki': 118,
#  'hoş': 119,
#  'eğer': 120,
#  'arasında': 121,
#  'sahip': 122,
#  'merak': 123,
#  'müthiş': 124,
#  'geçen': 125,
#  'kaliteli': 126,
#  'iş': 127,
#  'sinemada': 128,
#  'arkadaşlar': 129,
#  'aşk': 130,
#  'yorum': 131,
#  'üzerine': 132,
#  'güzeldi': 133,
#  'yazık': 134,
#  'mı': 135,
#  'kurgu': 136,
#  'belli': 137,
#  'oyunculuklar': 138,
#  'klasik': 139,
#  'zor': 140,
#  'vakit': 141,
#  'dolu': 142,
#  'beğendim': 143,
#  'in': 144,
#  'para': 145,
#  'hikaye': 146,
#  'vardı': 147,
#  'sonuna': 148,
#  'şeyler': 149,
#  'gereksiz': 150,
#  'derece': 151,
#  'boş': 152,
#  'filmini': 153,
#  'hakkında': 154,
#  'sıradan': 155,
#  'insanı': 156,
#  'değer': 157,
#  'vasat': 158,
#  'boyunca': 159,
#  'yüzden': 160,
#  'ayrı': 161,
#  'savaş': 162,
#  'küçük': 163,
#  'amerikan': 164,
#  'hemen': 165,
#  'insanın': 166,
#  'ediyorum': 167,
#  'izlenmesi': 168,
#  'varsa': 169,
#  'işte': 170,
#  'olabilir': 171,
#  'yıl': 172,
#  'tabi': 173,
#  'geldi': 174,
#  'yönetmenin': 175,
#  'olmasına': 176,
#  'filminde': 177,
#  'ikinci': 178,
#  'i̇yi': 179,
#  'üzerinden': 180,
#  'ilginç': 181,
#  'çocuk': 182,
#  'fi': 183,
#  'düşünüyorum': 184,
#  'görsel': 185,
#  'izlemeye': 186,
#  'kadın': 187,
#  'içine': 188,
#  'karakter': 189,
#  'animasyon': 190,
#  'i̇lk': 191,
#  'birlikte': 192,
#  'sanırım': 193,
#  'hayatımda': 194,
#  'zamanda': 195,
#  'filmlerini': 196,
#  'genel': 197,
#  'd': 198,
#  'kısa': 199,
#  'hak': 200,
#  'tarafından': 201,
#  'romantik': 202,
#  'olacak': 203,
#  'oyunculuğu': 204,
#  'serinin': 205,
#  'uzak': 206,
#  'diyebilirim': 207,
#  'derim': 208,
#  'yapılmış': 209,
#  'dram': 210,
#  'senaryosu': 211,
#  'karşı': 212,
#  'tarz': 213,
#  'eski': 214,
#  'ana': 215,
#  'insanların': 216,
#  'yada': 217,
#  'seyirler': 218,
#  'görmek': 219,
#  'kişi': 220,
#  'kelimeyle': 221,
#  'saat': 222,
#  'gün': 223,
#  'eder': 224,
#  'kere': 225,
#  'filmle': 226,
#  'dünya': 227,
#  'anlatan': 228,
#  'fena': 229,
#  'hikayesi': 230,
#  'inanılmaz': 231,
#  'filmlerin': 232,
#  'bende': 233,
#  'kaybı': 234,
#  'insanlar': 235,
#  'gelen': 236,
#  'resmen': 237,
#  'evet': 238,
#  'karakteri': 239,
#  'iyiydi': 240,
#  'sürükleyici': 241,
#  'yaptığı': 242,
#  'yapılan': 243,
#  'guzel': 244,
#  'hele': 245,
#  'kız': 246,
#  'kaç': 247,
#  'değildi': 248,
#  'yapan': 249,
#  'birşey': 250,
#  'an': 251,
#  'ağır': 252,
#  'göz': 253,
#  'birçok': 254,
#  'şimdi': 255,
#  'karakterler': 256,
#  'pişman': 257,
#  'çıkan': 258,
#  'bır': 259,
#  'çekilmiş': 260,
#  'adamın': 261,
#  'oscar': 262,
#  'bişey': 263,
#  'yapımı': 264,
#  'tür': 265,
#  'yüksek': 266,
#  'sinemaya': 267,
#  'duygusal': 268,
#  'puanı': 269,
#  'dikkat': 270,
#  'zamanlarda': 271,
#  'alan': 272,
#  'tahmin': 273,
#  'açıkçası': 274,
#  'sürekli': 275,
#  'bi̇r': 276,
#  'ın': 277,
#  'bol': 278,
#  'sonuç': 279,
#  'altında': 280,
#  'vizyona': 281,
#  'sağlam': 282,
#  'hayat': 283,
#  'keşke': 284,
#  'başyapıt': 285,
#  'performansı': 286,
#  'filmlere': 287,
#  'lazım': 288,
#  'birkaç': 289,
#  'çoğu': 290,
#  'yere': 291,
#  'geliyor': 292,
#  'of': 293,
#  'olay': 294,
#  'sona': 295,
#  'aile': 296,
#  'sırf': 297,
#  'anda': 298,
#  'gerçekçi': 299,
#  'yinede': 300,
#  'keyifli': 301,
#  'keyif': 302,
#  'yanında': 303,
#  'oyuncuların': 304,
#  'klişe': 305,
#  'hayran': 306,
#  'geri': 307,
#  'demek': 308,
#  'sıkılmadan': 309,
#  'usta': 310,
#  'olmasa': 311,
#  'öncelikle': 312,
#  'fazlasıyla': 313,
#  'veren': 314,
#  'vardır': 315,
#  'filmlerinde': 316,
#  'azından': 317,
#  'süre': 318,
#  'üzerinde': 319,
#  'rol': 320,
#  'gittim': 321,
#  'fılm': 322,
#  'adına': 323,
#  'genç': 324,
#  'dakika': 325,
#  'ii': 326,
#  'açısından': 327,
#  'yakın': 328,
#  'başına': 329,
#  'adeta': 330,
#  'yanı': 331,
#  'neredeyse': 332,
#  'filmlerinin': 333,
#  'filminden': 334,
#  'baştan': 335,
#  'tarzı': 336,
#  'filmlerde': 337,
#  'ilgi': 338,
#  'filim': 339,
#  'değişik': 340,
#  'müzik': 341,
#  'yerde': 342,
#  'anlamda': 343,
#  'izledikten': 344,
#  'olaylar': 345,
#  'performans': 346,
#  'gercekten': 347,
#  'erkek': 348,
#  'sanat': 349,
#  'kalan': 350,
#  'şeyi': 351,
#  'filmlerine': 352,
#  'hoşuma': 353,
#  'açık': 354,
#  'yanlış': 355,
#  'final': 356,
#  'sapan': 357,
#  'sahnede': 358,
#  'zayıf': 359,
#  'ön': 360,
#  'etmek': 361,
#  'ses': 362,
#  'türlü': 363,
#  'buldum': 364,
#  'kalmış': 365,
#  'filminin': 366,
#  'maalesef': 367,
#  'hakkını': 368,
#  'umarım': 369,
#  'üç': 370,
#  'yapmış': 371,
#  'yoktu': 372,
#  'aldığı': 373,
#  'vs': 374,
#  'başta': 375,
#  'ara': 376,
#  'çizgi': 377,
#  'john': 378,
#  'sakın': 379,
#  'icin': 380,
#  'düşük': 381,
#  'baya': 382,
#  'ele': 383,
#  'görüntü': 384,
#  'sinemasının': 385,
#  'kamera': 386,
#  'veriyor': 387,
#  'zevk': 388,
#  'izlenebilir': 389,
#  'şiddetle': 390,
#  'şunu': 391,
#  'izlemenizi': 392,
#  'ötesi': 393,
#  'kolay': 394,
#  'durum': 395,
#  'herşey': 396,
#  'gidin': 397,
#  'söz': 398,
#  'anlatıyor': 399,
#  'kabul': 400,
#  'yavaş': 401,
#  'filmine': 402,
#  'içerisinde': 403,
#  'tatmin': 404,
#  'izleme': 405,
#  'oldum': 406,
#  'sonunu': 407,
#  'beraber': 408,
#  'müzikleri': 409,
#  'tv': 410,
#  'yeniden': 411,
#  'yönetmeni': 412,
#  'izlemesi': 413,
#  'hitap': 414,
#  'güçlü': 415,
#  'mutlu': 416,
#  'gidip': 417,
#  'kusursuz': 418,
#  'mümkün': 419,
#  'efektler': 420,
#  'verdiği': 421,
#  'açıdan': 422,
#  'işi': 423,
#  'hollywood': 424,
#  'baş': 425,
#  'sevdiğim': 426,
#  'aşırı': 427,
#  'özel': 428,
#  'oynamış': 429,
#  'kırıklığı': 430,
#  'alıp': 431,
#  'karar': 432,
#  'müzikler': 433,
#  'den': 434,
#  'ünlü': 435,
#  'fantastik': 436,
#  'lütfen': 437,
#  'ederi': 438,
#  'bilim': 439,
#  'dolayı': 440,
#  'kurgusu': 441,
#  'üzere': 442,
#  'dair': 443,
#  'merakla': 444,
#  'doğrusu': 445,
#  'bakış': 446,
#  'tane': 447,
#  'yerinde': 448,
#  'kesin': 449,
#  'izlemedim': 450,
#  'üst': 451,
#  'ufak': 452,
#  'yıllarda': 453,
#  'çekici': 454,
#  'mesaj': 455,
#  'giden': 456,
#  'konusunda': 457,
#  'ciddi': 458,
#  'adı': 459,
#  'başında': 460,
#  'tom': 461,
#  'sene': 462,
#  'sineması': 463,
#  'bugün': 464,
#  'önceki': 465,
#  'beğenmedim': 466,
#  'hayatta': 467,
#  'oynadığı': 468,
#  'robert': 469,
#  'duygu': 470,
#  'hale': 471,
#  'seri': 472,
#  'çalışan': 473,
#  'yapıyor': 474,
#  'çıkmış': 475,
#  'dünyanın': 476,
#  'konuyu': 477,
#  'tercih': 478,
#  'yol': 479,
#  'yalnız': 480,
#  'degil': 481,
#  'istiyorum': 482,
#  'önüne': 483,
#  'eminim': 484,
#  'iç': 485,
#  'asıl': 486,
#  'doğal': 487,
#  'anlamıyla': 488,
#  'kısacası': 489,
#  'bilmiyorum': 490,
#  'kadrosu': 491,
#  'efsane': 492,
#  'almış': 493,
#  'izlenmeye': 494,
#  'izlemiştim': 495,
#  'derecede': 496,
#  'izlenmeli': 497,
#  'gitti': 498,
#  'gelecek': 499,
#  'üstüne': 500,
#  'yıllar': 501,
#  'izlemeden': 502,
#  'geçmiş': 503,
#  'boşa': 504,
#  'gitmeyin': 505,
#  'kelime': 506,
#  'arasındaki': 507,
#  'işlenmiş': 508,
#  'rahatsız': 509,
#  'olmamış': 510,
#  'beyaz': 511,
#  'karakterlerin': 512,
#  'başrol': 513,
#  'arkadaş': 514,
#  'kara': 515,
#  'gelmiş': 516,
#  'olmadığı': 517,
#  'izlenebilecek': 518,
#  'oynayan': 519,
#  'sahnelerde': 520,
#  'çıkıyor': 521,
#  'vermek': 522,
#  'tabiki': 523,
#  'şöyle': 524,
#  'dün': 525,
#  'olurdu': 526,
#  'adlı': 527,
#  'normal': 528,
#  'baba': 529,
#  'be': 530,
#  'mesela': 531,
#  'alıyor': 532,
#  'mantık': 533,
#  'geçiyor': 534,
#  'orta': 535,
#  'gelir': 536,
#  'heyecan': 537,
#  'genelde': 538,
#  'aday': 539,
#  'hemde': 540,
#  'james': 541,
#  'herhalde': 542,
#  'adamı': 543,
#  'evde': 544,
#  'hayatı': 545,
#  'izleyip': 546,
#  'takip': 547,
#  'hızlı': 548,
#  'benzer': 549,
#  'diyorum': 550,
#  'izlemeyin': 551,
#  'sevenler': 552,
#  'diyaloglar': 553,
#  'başından': 554,
#  'filmdir': 555,
#  'fark': 556,
#  'uygun': 557,
#  'dedim': 558,
#  'birde': 559,
#  'geçirmek': 560,
#  'oyuncuları': 561,
#  'kat': 562,
#  'olabilirdi': 563,
#  'tarihinin': 564,
#  'etkili': 565,
#  'neler': 566,
#  'sefer': 567,
#  'başlıyor': 568,
#  'çeken': 569,
#  'seyirciyi': 570,
#  'kendimi': 571,
#  'harikaydı': 572,
#  'yılın': 573,
#  'eksik': 574,
#  'dönem': 575,
#  'zamandır': 576,
#  'insanları': 577,
#  'ince': 578,
#  'derin': 579,
#  'dvd': 580,
#  'yılında': 581,
#  'akıcı': 582,
#  'izlenir': 583,
#  'yapmaya': 584,
#  'yeri': 585,
#  'gelince': 586,
#  'dk': 587,
#  'hayatın': 588,
#  'gece': 589,
#  'yaş': 590,
#  'seyirciye': 591,
#  'iyisi': 592,
#  'sıra': 593,
#  'olmus': 594,
#  'kızın': 595,
#  'tebrik': 596,
#  'elde': 597,
#  'belgesel': 598,
#  'konuda': 599,
#  'onların': 600,
#  'kırıklığına': 601,
#  'bekliyorum': 602,
#  'yapıt': 603,
#  'hikayenin': 604,
#  'olmadığını': 605,
#  'al': 606,
#  'sonuçta': 607,
#  'edici': 608,
#  'çekilen': 609,
#  'orjinal': 610,
#  'psikolojik': 611,
#  'aşık': 612,
#  'olayı': 613,
#  'dahil': 614,
#  'sıcak': 615,
#  'ortada': 616,
#  'michael': 617,
#  'sonraki': 618,
#  'gerekir': 619,
#  'emek': 620,
#  'paraya': 621,
#  'seven': 622,
#  'çocuklar': 623,
#  'dediğim': 624,
#  'kaçırmayın': 625,
#  'çekim': 626,
#  'olumsuz': 627,
#  'olacağını': 628,
#  'söylemek': 629,
#  'su': 630,
#  'saygı': 631,
#  'bilimkurgu': 632,
#  'yorumlara': 633,
#  'özgün': 634,
#  'aldım': 635,
#  'kahraman': 636,
#  'anlamsız': 637,
#  'rolü': 638,
#  'istediği': 639,
#  'işin': 640,
#  'sayesinde': 641,
#  'karakterleri': 642,
#  'macera': 643,
#  'oldugunu': 644,
#  'not': 645,
#  'ettiği': 646,
#  'yan': 647,
#  'karanlık': 648,
#  'yüzünden': 649,
#  'olunca': 650,
#  'hayatını': 651,
#  'yarım': 652,
#  'alt': 653,
#  'fi̇lm': 654,
#  'anlatmak': 655,
#  'kadının': 656,
#  'bunları': 657,
#  'olsada': 658,
#  'alakası': 659,
#  'yandan': 660,
#  'yabancı': 661,
#  'kotu': 662,
#  'devamı': 663,
#  'fi̇lmi̇n': 664,
#  'başarısız': 665,
#  'kült': 666,
#  'anlamadım': 667,
#  'istiyorsanız': 668,
#  'izlemiş': 669,
#  'kitabı': 670,
#  'anlam': 671,
#  'dört': 672,
#  'hayranı': 673,
#  'sade': 674,
#  'sürü': 675,
#  'espriler': 676,
#  'zamana': 677,
#  'aksine': 678,
#  'bı': 679,
#  'kişinin': 680,
#  'olsaydı': 681,
#  'tatlı': 682,
#  'göze': 683,
#  'anne': 684,
#  'üstelik': 685,
#  'etkisi': 686,
#  'can': 687,
#  'kadro': 688,
#  'yaa': 689,
#  'etmiş': 690,
#  'fransız': 691,
#  'bakımından': 692,
#  'kafa': 693,
#  'imza': 694,
#  'ilerleyen': 695,
#  'hava': 696,
#  'tarihi': 697,
#  'ismi': 698,
#  'ettim': 699,
#  'i̇şte': 700,
#  'garip': 701,
#  'iyice': 702,
#  'sahnesinde': 703,
#  'dövüş': 704,
#  'oyunculukları': 705,
#  'yerden': 706,
#  'anlamak': 707,
#  'dramatik': 708,
#  'zorunda': 709,
#  'izleyici': 710,
#  'karşımıza': 711,
#  'çıkarmış': 712,
#  'onları': 713,
#  'yaşadığı': 714,
#  'dünyada': 715,
#  'insana': 716,
#  'vermiş': 717,
#  'araya': 718,
#  'finali': 719,
#  'olağanüstü': 720,
#  'hayata': 721,
#  'burda': 722,
#  'nedir': 723,
#  'gördüm': 724,
#  'yaşayan': 725,
#  'ardından': 726,
#  'görünce': 727,
#  'çarpıcı': 728,
#  'cidden': 729,
#  'rezalet': 730,
#  'kitap': 731,
#  'türü': 732,
#  'samimi': 733,
#  'iğrenç': 734,
#  'çıktı': 735,
#  'verilen': 736,
#  'haline': 737,
#  'ders': 738,
#  'gösterime': 739,
#  'ödül': 740,
#  'savaşı': 741,
#  'keyifle': 742,
#  'biçimde': 743,
#  'yorumlar': 744,
#  'gösteriyor': 745,
#  'olma': 746,
#  'yerini': 747,
#  'isteyen': 748,
#  'beğendiğim': 749,
#  'yerlerde': 750,
#  'hadi': 751,
#  'verdim': 752,
#  'karakterin': 753,
#  'yaşam': 754,
#  'oyuncusu': 755,
#  'sert': 756,
#  'oldugu': 757,
#  'abartılı': 758,
#  'anlatım': 759,
#  'hafta': 760,
#  'serisi': 761,
#  'tadında': 762,
#  'zamanki': 763,
#  'defalarca': 764,
#  'rolünde': 765,
#  'izleyiciyi': 766,
#  'emeği': 767,
#  'beklediğim': 768,
#  'ister': 769,
#  'mesajlar': 770,
#  'söyleyebilirim': 771,
#  'diyor': 772,
#  'bunların': 773,
#  'numara': 774,
#  'gişe': 775,
#  'derken': 776,
#  'gençlik': 777,
#  'gördüğüm': 778,
#  'aklıma': 779,
#  'izlenecek': 780,
#  'david': 781,
#  'senaryonun': 782,
#  'arka': 783,
#  'sorun': 784,
#  'performansları': 785,
#  'izleyen': 786,
#  'yarısı': 787,
#  'izlemeyi': 788,
#  'olmadan': 789,
#  'soru': 790,
#  'teknik': 791,
#  'ölüm': 792,
#  'konuya': 793,
#  'gösteren': 794,
#  'fragmanı': 795,
#  'yönetmenlik': 796,
#  'kalıyor': 797,
#  'hic': 798,
#  'eleştiri': 799,
#  'bayıldım': 800,
#  'olayları': 801,
#  'örnek': 802,
#  'türkçe': 803,
#  'sebep': 804,
#  'efektleri': 805,
#  'kısaca': 806,
#  'emin': 807,
#  'yola': 808,
#  'yaşanan': 809,
#  'adını': 810,
#  'kendinizi': 811,
#  'kan': 812,
#  'jim': 813,
#  'türünün': 814,
#  'adamlar': 815,
#  'ı': 816,
#  'değildir': 817,
#  'olayların': 818,
#  'küfür': 819,
#  'niro': 820,
#  'şeyleri': 821,
#  'gerekiyor': 822,
#  'li': 823,
#  'planda': 824,
#  'cem': 825,
#  'olmaya': 826,
#  'yerli': 827,
#  'zeki': 828,
#  'birini': 829,
#  'işler': 830,
#  'olanlar': 831,
#  'geç': 832,
#  'ters': 833,
#  'acı': 834,
#  'altın': 835,
#  'sey': 836,
#  'yaratıcı': 837,
#  'olumlu': 838,
#  'si': 839,
#  'ilerliyor': 840,
#  'nefret': 841,
#  'valla': 842,
#  'olmasını': 843,
#  'seyirci': 844,
#  'unutulmaz': 845,
#  'yorumları': 846,
#  'arasına': 847,
#  'birbirine': 848,
#  'i̇yi̇': 849,
#  'değilim': 850,
#  'başarılıydı': 851,
#  'üstünde': 852,
#  'boşuna': 853,
#  'izleyi': 854,
#  'sinemanın': 855,
#  'ait': 856,
#  'sergilemiş': 857,
#  'başladı': 858,
#  'şiddet': 859,
#  'yeterli': 860,
#  'aldı': 861,
#  'dediği': 862,
#  'beş': 863,
#  'johnny': 864,
#  'oyunculuğunu': 865,
#  'şahane': 866,
#  'hayli': 867,
#  'başlar': 868,
#  'herşeyi': 869,
#  'yapmışlar': 870,
#  'ifade': 871,
#  'izleyince': 872,
#  'diyen': 873,
#  'idi': 874,
#  'filmiydi': 875,
#  'dönemde': 876,
#  'senaryoya': 877,
#  'tadı': 878,
#  'atmosfer': 879,
#  'çıkar': 880,
#  'yanlari': 881,
#  'yana': 882,
#  'nokta': 883,
#  'havası': 884,
#  'izledigim': 885,
#  'dünyaya': 886,
#  'star': 887,
#  'korkunç': 888,
#  'la': 889,
#  'sağlık': 890,
#  'izlediğimde': 891,
#  'abd': 892,
#  'hariç': 893,
#  'içi': 894,
#  'bitti': 895,
#  'çektiği': 896,
#  'kötüydü': 897,
#  'henüz': 898,
#  'türkiyede': 899,
#  'yarısında': 900,
#  'yılmaz': 901,
#  'bruce': 902,
#  'jack': 903,
#  'benziyor': 904,
#  'olabilecek': 905,
#  'we': 906,
#  'amerika': 907,
#  'konusunu': 908,
#  'türden': 909,
#  'olduğuna': 910,
#  'diken': 911,
#  'süresi': 912,
#  'dalga': 913,
#  'puanım': 914,
#  'oyun': 915,
#  'gülmekten': 916,
#  'yardımcı': 917,
#  'içindeki': 918,
#  'der': 919,
#  'dans': 920,
#  'sıkıldım': 921,
#  'birden': 922,
#  'kitabını': 923,
#  'seyrettim': 924,
#  'nadir': 925,
#  'yıldız': 926,
#  'biriydi': 927,
#  'bayağı': 928,
#  'sebebi': 929,
#  'kaldı': 930,
#  'rahatlıkla': 931,
#  'kızı': 932,
#  'isteyenler': 933,
#  'olmu': 934,
#  'yılların': 935,
#  'şahsen': 936,
#  'insanlara': 937,
#  'gerektiğini': 938,
#  'bizlere': 939,
#  'havada': 940,
#  'yapı': 941,
#  'adım': 942,
#  'görüyoruz': 943,
#  'bond': 944,
#  'allah': 945,
#  'olun': 946,
#  'izleyiciye': 947,
#  'boyle': 948,
#  'yarı': 949,
#  'el': 950,
#  'kalitesi': 951,
#  'nedense': 952,
#  'bakalım': 953,
#  'şeyin': 954,
#  'bölüm': 955,
#  'önceden': 956,
#  'bölümü': 957,
#  'güldüm': 958,
#  'çocuğun': 959,
#  'ha': 960,
#  'başarıyor': 961,
#  'anlamlı': 962,
#  'ziyade': 963,
#  'yoktur': 964,
#  'sinemadan': 965,
#  'olamaz': 966,
#  'dünyayı': 967,
#  'haliyle': 968,
#  'ıyı': 969,
#  'rolünü': 970,
#  'filmiyle': 971,
#  'etmiyor': 972,
#  'konunun': 973,
#  'verici': 974,
#  'bide': 975,
#  'olduğum': 976,
#  'olmadı': 977,
#  'suç': 978,
#  'alması': 979,
#  'net': 980,
#  'sırada': 981,
#  'aşkı': 982,
#  'birbirinden': 983,
#  'ay': 984,
#  'tat': 985,
#  'western': 986,
#  'belkide': 987,
#  'paranıza': 988,
#  'nedeni': 989,
#  'desem': 990,
#  'efekt': 991,
#  'sabırsızlıkla': 992,
#  'sakin': 993,
#  'roman': 994,
#  'dizi': 995,
#  'yarıda': 996,
#  'fılmı': 997,
#  'örneği': 998,
#  'te': 999,
#  'hata': 1000,
#  ...}

# %%
#train ve test verilerini tokenleştirme
X_train_tokens = tokenizer.texts_to_sequences(X_train)
X_test_tokens = tokenizer.texts_to_sequences(X_test)

print(X_train[20])
print(X_train_tokens[20])
df.head()
# Out:
# moviemaxte vermeye başladıklarından seyrettim seyretmeye devam edicemmtürünün izlenesi örneklerindendirbeğenmeyenlere çok şaşırıyorumbi korku filmi şaşırtabilir
# [1768, 924, 2562, 95, 1559, 2, 52, 3]
#                                              comment      film_name  point  \
# 0  jean reno denince zaten leon filmi gelir akla ...  Sevginin Gücü    1.0
# 1  ekşın falan izlemek istiyorsanız eğer bunu izl...  Sevginin Gücü    1.0
# 2  bu yapım hakkında öyle çok şey yazabilirim ki ...  Sevginin Gücü    1.0
# 3  finali yeter sting  shape of my heart    bazıl...  Sevginin Gücü    1.0
# 4  jean reno  bu adam kusursuz biri  ve oyunculug...  Sevginin Gücü    1.0
#
#                            comment_without_stopwords
# 0  jean reno denince leon filmi gelir akla izleme...
# 1  ekşın izlemek istiyorsanız eğer izlemeyiin dos...
# 2  yapım hakkında öyle çok şey yazabilirim kitap ...
# 3  finali yeter sting shape of my heart bazıları ...
# 4  jean reno adam kusursuz oyunculugu müthiş film...

# %%
#padding işlemi
maxlen = 150
X_train_pad = pad_sequences(X_train_tokens, maxlen = maxlen) 
X_test_pad = pad_sequences(X_test_tokens, maxlen = maxlen)

print(X_train_pad.shape)
print(X_test_pad.shape)
# Out:
# (54986, 150)
# (13747, 150)

# %%
embedding_out = 50
lstm_out = 196
model = Sequential()
model.add(Embedding(input_dim = num_words, output_dim = embedding_out, input_length = maxlen))
model.add(SpatialDropout1D(0.4))
model.add(LSTM(lstm_out, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(1, activation = "sigmoid"))
model.compile(optimizer = 'adam', loss = "binary_crossentropy", metrics = ["accuracy"])
model.summary()
X_train_pad = np.array(X_train_pad)
y_train = np.array(y_train)

model.fit(X_train_pad, y_train, epochs = 5, batch_size = 256)

model.save("model1.h5")
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 150, 50)           500000
# _________________________________________________________________
# spatial_dropout1d (SpatialDr (None, 150, 50)           0
# _________________________________________________________________
# lstm (LSTM)                  (None, 196)               193648
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 197
# =================================================================
# Total params: 693,845
# Trainable params: 693,845
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 215/215 [==============================] - 200s 919ms/step - loss: 0.5190 - accuracy: 0.7439
# Epoch 2/5
# 215/215 [==============================] - 198s 921ms/step - loss: 0.4123 - accuracy: 0.8211
# Epoch 3/5
# 215/215 [==============================] - 201s 937ms/step - loss: 0.3859 - accuracy: 0.8350
# Epoch 4/5
# 215/215 [==============================] - 206s 958ms/step - loss: 0.3681 - accuracy: 0.8458
# Epoch 5/5
# 215/215 [==============================] - 198s 923ms/step - loss: 0.3518 - accuracy: 0.8534

# %%
embedding_out = 50
model2 = Sequential()
model2.add(Embedding(input_dim = num_words, output_dim = embedding_out, input_length = maxlen))
model2.add(GRU(units = 32, return_sequences = True))
model2.add(GRU(units = 16, return_sequences = True))
model2.add(GRU(units = 8))
model2.add(Dense(1, activation = "sigmoid"))
model2.compile(optimizer = 'adam', loss = "binary_crossentropy", metrics = ["accuracy"])
model2.summary()
X_train_pad = np.array(X_train_pad)
y_train = np.array(y_train)

model2.fit(X_train_pad, y_train, epochs = 5, batch_size = 256)
model2.save("model2.h5")
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, 150, 50)           500000
# _________________________________________________________________
# gru_11 (GRU)                 (None, 150, 32)           8064
# _________________________________________________________________
# gru_12 (GRU)                 (None, 150, 16)           2400
# _________________________________________________________________
# gru_13 (GRU)                 (None, 8)                 624
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 511,097
# Trainable params: 511,097
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 215/215 [==============================] - 9s 23ms/step - loss: 0.5088 - accuracy: 0.7496
# Epoch 2/5
# 215/215 [==============================] - 5s 24ms/step - loss: 0.3973 - accuracy: 0.8296
# Epoch 3/5
# 215/215 [==============================] - 5s 23ms/step - loss: 0.3716 - accuracy: 0.8456 0s - loss: 0.3
# Epoch 4/5
# 215/215 [==============================] - 5s 23ms/step - loss: 0.3514 - accuracy: 0.8589
# Epoch 5/5
# 215/215 [==============================] - 5s 23ms/step - loss: 0.3274 - accuracy: 0.8721

# %%
embedding_out = 50
model3 = Sequential()
model3.add(Embedding(input_dim = num_words, output_dim = embedding_out, input_length = maxlen))
model3.add(GRU(units = 32, return_sequences = True))
model3.add(GRU(units = 16, return_sequences = True))
model3.add(GRU(units = 8, return_sequences = True))
model3.add(GRU(units = 4))
model3.add(Dense(1, activation = "sigmoid"))

opt=SGD(learning_rate=0.1,momentum=0.9)

model3.compile(optimizer = opt, loss = "binary_crossentropy", metrics = ["accuracy"])
model3.summary()
X_train_pad = np.array(X_train_pad)
y_train = np.array(y_train)

model3.fit(X_train_pad, y_train, epochs = 5, batch_size = 256)
model3.save("model3.h5")
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_5 (Embedding)      (None, 150, 50)           500000
# _________________________________________________________________
# gru_14 (GRU)                 (None, 150, 32)           8064
# _________________________________________________________________
# gru_15 (GRU)                 (None, 150, 16)           2400
# _________________________________________________________________
# gru_16 (GRU)                 (None, 150, 8)            624
# _________________________________________________________________
# gru_17 (GRU)                 (None, 4)                 168
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 511,261
# Trainable params: 511,261
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 215/215 [==============================] - 11s 26ms/step - loss: 0.6591 - accuracy: 0.6313
# Epoch 2/5
# 215/215 [==============================] - 5s 25ms/step - loss: 0.6368 - accuracy: 0.6450
# Epoch 3/5
# 215/215 [==============================] - 5s 24ms/step - loss: 0.5351 - accuracy: 0.7344
# Epoch 4/5
# 215/215 [==============================] - 5s 25ms/step - loss: 0.4707 - accuracy: 0.7841
# Epoch 5/5
# 215/215 [==============================] - ETA: 0s - loss: 0.4264 - accuracy: 0.81 - 5s 26ms/step - loss: 0.4263 - accuracy: 0.8130

# %%
#tek bir yorum için duygu tahmini yapılması
def comment_pred(comment, model):
    comment = [comment]
    comment = tokenizer.texts_to_sequences(comment)
    comment = pad_sequences(comment, maxlen=maxlen, dtype='int32', value=0)

    sentiment = model.predict(comment,batch_size=1,verbose = 2)[0]

    if(sentiment < 0.5):
        print("negative")
    elif (sentiment >= 0.5):
        print("positive")

    print(sentiment)


comment = 'çok güzel bir film'
comment_pred(comment, model)
comment_pred(comment, model2)
comment_pred(comment, model3)
# Out:
# 1/1 - 0s
# positive
# [0.79165864]
# 1/1 - 1s
# positive
# [0.8537489]
# 1/1 - 1s
# positive
# [0.6655347]

# %%
#oluşturulan modelin test verisindeki yorumlar için yapılan yanlış tahmin sayıları
def uncorrect_preds(model):
    y_pred = model.predict(X_test_pad, verbose = 1)
    y_pred = y_pred.T[0]
    array_pred = np.array([1.0 if p > 0.5 else 0.0 for p in y_pred])
    array_true = np.array(y_test)
    incorrect = np.where(array_pred != array_true)
    incorrect = incorrect[0]
    print(len(incorrect))


uncorrect_preds(model)
uncorrect_preds(model2)
uncorrect_preds(model3)
# Out:
# 430/430 [==============================] - 46s 106ms/step
# 2877
# 430/430 [==============================] - 2s 5ms/step
# 2902
# 430/430 [==============================] - 3s 6ms/step
# 3032
